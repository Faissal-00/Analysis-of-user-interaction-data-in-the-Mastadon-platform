# %%
from mastodon import Mastodon
from dotenv import load_dotenv
import os
from hdfs import InsecureClient
import datetime

load_dotenv()

# Connect to the mastodon API
mastodon = Mastodon(
    client_id=os.getenv('MASTODON_CLIENT_ID'),
    client_secret=os.getenv('MASTODON_CLIENT_SECRET'),
    access_token=os.getenv('MASTODON_ACCESS_TOKEN'),
    api_base_url="https://mastodon.social"
)

# Initialize an HDFS client
hdfs_client = InsecureClient(os.getenv('HDFS_CLIENT_URL'), user=os.getenv('HDFS_CLIENT_USER'))


# get current date and time
now = datetime.datetime.now()
directory_path = '/raw/'+ str(now.year) + '-' + str(now.month) + '-' + str(now.day)

# Check if the directory already exists
if not hdfs_client.status(directory_path, strict=False):
    hdfs_client.makedirs(directory_path)

# Define the HDFS path where you want to save the data
hdfs_path = directory_path + '/' + str(now.hour) + '-' + str(now.minute) + '/mastodon.txt'

public_posts = mastodon.timeline_public(limit=10)

i = 0
# Create a text file to store the Mastodon data
with hdfs_client.write(hdfs_path) as writer:
    for post in public_posts:
        writer.write(f'Post{i}: {post} \n')
        i += 1

print('Data saved successfully to HDFS : ' + hdfs_path)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connectionpool.py:413, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     412 if chunked:
# --> 413     conn.request_chunked(method, url, **httplib_request_kw)
#     414 else:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connection.py:264, in HTTPConnection.request_chunked(self, method, url, body, headers)
#     263     self.putheader("Transfer-Encoding", "chunked")
# --> 264 self.endheaders()
#     266 if body is not None:
#
# File ~\miniconda3\envs\myenv\Lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\miniconda3\envs\myenv\Lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File ~\miniconda3\envs\myenv\Lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000021112621F10>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\miniconda3\envs\myenv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='laptop-1us3gu3j.', port=9864): Max retries exceeded with url: /webhdfs/v1/raw/2023-10-19/8-52/mastodon.txt?op=CREATE&user.name=hadoop&namenoderpcaddress=0.0.0.0:9000&createflag=&createparent=true&overwrite=false&user.name=hadoop (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021112621F10>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 36
#      34 i = 0
#      35 # Create a text file to store the Mastodon data
# ---> 36 with hdfs_client.write(hdfs_path) as writer:
#      37     for post in public_posts:
#      38         writer.write(f'Post{i}: {post} \n')
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\hdfs\util.py:104, in AsyncWriter.__exit__(self, exc_type, exc_value, traceback)
#     102   self._reader.join()
#     103 if self._err:
# --> 104   raise self._err # pylint: disable=raising-bad-type
#     105 else:
#     106   _logger.debug('Child terminated without errors.')
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\hdfs\util.py:76, in AsyncWriter.__enter__.<locals>.consumer(data)
#      74 try:
#      75   _logger.debug('Starting consumer.')
# ---> 76   self._consumer(data)
#      77 except Exception as err: # pylint: disable=broad-except
#      78   _logger.exception('Exception in child.')
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\hdfs\client.py:509, in Client.write.<locals>.consumer(_data)
#     507 def consumer(_data):
#     508   """Thread target."""
# --> 509   res = self._request(
#     510     method='POST' if append else 'PUT',
#     511     url=loc,
#     512     data=(c.encode(encoding) for c in _data) if encoding else _data,
#     513   )
#     514   if not res:
#     515     raise _to_error(res)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\hdfs\client.py:209, in Client._request(self, method, url, **kwargs)
#     199 def _request(self, method, url, **kwargs):
#     200   r"""Send request to WebHDFS API.
#     201
#     202   :param method: HTTP verb.
#    (...)
#     207
#     208   """
# --> 209   return self._session.request(
#     210     method=method,
#     211     url=url,
#     212     timeout=self._timeout,
#     213     headers={'content-type': 'application/octet-stream'}, # For HttpFS.
#     214     **kwargs
#     215   )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='laptop-1us3gu3j.', port=9864): Max retries exceeded with url: /webhdfs/v1/raw/2023-10-19/8-52/mastodon.txt?op=CREATE&user.name=hadoop&namenoderpcaddress=0.0.0.0:9000&createflag=&createparent=true&overwrite=false&user.name=hadoop (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021112621F10>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))

# %%
public_posts
# Out:
# [{'id': 111260595831428351,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 39, tzinfo=tzutc()),
#   'in_reply_to_id': 111260593625955885,
#   'in_reply_to_account_id': 110730813077137029,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://neuromatch.social/users/fsandhaeger/statuses/111260595607015490',
#   'url': 'https://neuromatch.social/@fsandhaeger/111260595607015490',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>Choice signals dynamically shifted from sensory to motor areas over the course of a trial.</p>',
#   'reblog': None,
#   'account': {'id': 110730813077137029,
#    'username': 'fsandhaeger',
#    'acct': 'fsandhaeger@neuromatch.social',
#    'display_name': 'fsandhaeger',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 7, 14, 0, 0, tzinfo=tzutc()),
#    'note': '<p>neuroscientist in tübingen. decision making, analysis methods, electrophysiology across scales.</p>',
#    'url': 'https://neuromatch.social/@fsandhaeger',
#    'uri': 'https://neuromatch.social/users/fsandhaeger',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/110/730/813/077/137/029/original/8f5ac50dc37104d7.jpg',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/110/730/813/077/137/029/original/8f5ac50dc37104d7.jpg',
#    'header': 'https://mastodon.social/headers/original/missing.png',
#    'header_static': 'https://mastodon.social/headers/original/missing.png',
#    'followers_count': 105,
#    'following_count': 368,
#    'statuses_count': 21,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': []},
#   'media_attachments': [{'id': 111260595648032779,
#     'type': 'image',
#     'url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/648/032/779/original/be14ba86867f2c55.png',
#     'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/648/032/779/small/be14ba86867f2c55.png',
#     'remote_url': 'https://neuromatch.social/system/media_attachments/files/111/260/595/531/858/969/original/40f9796aed38e74d.png',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 1010,
#       'height': 2053,
#       'size': '1010x2053',
#       'aspect': 0.4919629810034096},
#      'small': {'width': 337,
#       'height': 684,
#       'size': '337x684',
#       'aspect': 0.4926900584795322}},
#     'description': None,
#     'blurhash': 'UFRC-=_4%MjaM{xukBf5%MNFkCWBRQoyt7ae'}],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595817377032,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 51, 35, tzinfo=tzutc()),
#   'in_reply_to_id': 110780757209184968,
#   'in_reply_to_account_id': 506247,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'fr',
#   'uri': 'https://mamot.fr/users/EnercoConseils/statuses/111260591425175873',
#   'url': 'https://mamot.fr/@EnercoConseils/111260591425175873',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': "<p>Je vais vous donner mon opinion à mon tout, à l'aune de ma petite expérience. </p><p>La RE2020 ne va pas faire exploser les maisons en bois. D'abord, parce que le coût de la ressource bois a largement augmenté ses dernières années. D'autre part, en RE2020, les maisons bois pèchent au niveau de l'inertie ce qui augmentent les besoins, en particulier en rafraîchissement.</p>",
#   'reblog': None,
#   'account': {'id': 506247,
#    'username': 'EnercoConseils',
#    'acct': 'EnercoConseils@mamot.fr',
#    'display_name': 'Olivier Martinez :grue:',
#    'locked': True,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2018, 8, 30, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Consultant en performance énergétique et qualité environnementale bâtiment <a href="https://mamot.fr/tags/QEB" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>QEB</span></a>. Formateur et conférencier (<a href="https://mamot.fr/tags/simulationsdynamiques" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>simulationsdynamiques</span></a> : STD SED, analyse de cycle de vie <a href="https://mamot.fr/tags/ACV" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>ACV</span></a>, coût global, etc.). Membre <a href="https://nouvelle-aquitaine.constructionpaille.fr" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">nouvelle-aquitaine.constructio</span><span class="invisible">npaille.fr</span></a> et sociétaire <a href="https://ielo.coop" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">ielo.coop</span><span class="invisible"></span></a> (<a href="https://mamot.fr/tags/constructionpaille" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>constructionpaille</span></a>).</p><p>Consultant in energy performance and environmental quality. Instructor (<a href="https://mamot.fr/tags/DTS" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>DTS</span></a>, <a href="https://mamot.fr/tags/LCA" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LCA</span></a>, <a href="https://mamot.fr/tags/LCC" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LCC</span></a>, etc.). Involved in straw construction.</p>',
#    'url': 'https://mamot.fr/@EnercoConseils',
#    'uri': 'https://mamot.fr/users/EnercoConseils',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/000/506/247/original/8762e3c4dd98ed2a.png',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/000/506/247/original/8762e3c4dd98ed2a.png',
#    'header': 'https://files.mastodon.social/accounts/headers/000/506/247/original/43414942aea799b5.png',
#    'header_static': 'https://files.mastodon.social/accounts/headers/000/506/247/original/43414942aea799b5.png',
#    'followers_count': 208,
#    'following_count': 111,
#    'statuses_count': 1676,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [{'shortcode': 'grue',
#      'url': 'https://files.mastodon.social/cache/custom_emojis/images/000/179/472/original/fb27c77eedd5fd2f.png',
#      'static_url': 'https://files.mastodon.social/cache/custom_emojis/images/000/179/472/static/fb27c77eedd5fd2f.png',
#      'visible_in_picker': True}],
#    'fields': [{'name': 'Job',
#      'value': '<a href="http://enerco.free.fr" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">http://</span><span class="">enerco.free.fr</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Twitter',
#      'value': '<a href="https://www.twitter.com/EnercoConseils" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">twitter.com/EnercoConseils</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Blog',
#      'value': '<a href="https://enercoconseils.wordpress.com" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">enercoconseils.wordpress.com</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Département', 'value': 'Gironde (33)', 'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595803718108,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 40, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'fr',
#   'uri': 'https://lepoulsdumonde.com/users/bot_bp/statuses/111260595674124775',
#   'url': 'https://lepoulsdumonde.com/@bot_bp/111260595674124775',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>🍽️Les 70 ans de la Cocotte-Minute&nbsp;: chefs et cuisinier amateur ama donnent leur avis sur l’emblématique ustensile <a href="https://www.bienpublic.com/economie/2023/10/18/les-70-ans-de-la-cocotte-minute-ils-donnent-leur-avis-sur-l-emblematique-ustensile" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">bienpublic.com/economie/2023/1</span><span class="invisible">0/18/les-70-ans-de-la-cocotte-minute-ils-donnent-leur-avis-sur-l-emblematique-ustensile</span></a></p>',
#   'reblog': None,
#   'account': {'id': 109739396230937969,
#    'username': 'bot_bp',
#    'acct': 'bot_bp@lepoulsdumonde.com',
#    'display_name': 'Le Bien Public',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 1, 23, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Bot qui toot les infos du Bien Public depuis twitter.<br>Ecrit par <span class="h-card" translate="no"><a href="https://lepoulsdumonde.com/@nico" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>nico</span></a></span><br>tfr</p>',
#    'url': 'https://lepoulsdumonde.com/@bot_bp',
#    'uri': 'https://lepoulsdumonde.com/users/bot_bp',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/109/739/396/230/937/969/original/eaaa467d7450524a.jpg',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/109/739/396/230/937/969/original/eaaa467d7450524a.jpg',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/109/739/396/230/937/969/original/cb8f6782aae3764b.jpeg',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/109/739/396/230/937/969/original/cb8f6782aae3764b.jpeg',
#    'followers_count': 95,
#    'following_count': 0,
#    'statuses_count': 1629,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': []},
#   'media_attachments': [{'id': 111260595719418878,
#     'type': 'image',
#     'url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/719/418/878/original/bbce311eaebe65f0.jpg',
#     'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/719/418/878/small/bbce311eaebe65f0.jpg',
#     'remote_url': 'https://i.lepoulsdumonde.com/media_attachments/files/111/260/595/639/147/573/original/179fe63552bab86b.jpg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 841,
#       'height': 682,
#       'size': '841x682',
#       'aspect': 1.2331378299120235},
#      'small': {'width': 533,
#       'height': 432,
#       'size': '533x432',
#       'aspect': 1.2337962962962963}},
#     'description': 'un média posté par le compte Twitter',
#     'blurhash': 'UgIqoj^Is+S502kYRjV?xvMyRkoLj;xtofWX'}],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595763020092,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 41, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mastodon.online/users/50years_music/statuses/111260595724231572',
#   'url': 'https://mastodon.online/@50years_music/111260595724231572',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>"Since I Don\'t Have You" is a song written and composed by Jackie Taylor, James Beaumont, Janet Vogel, Joseph Rock, Joe Verscharen, Lennie Martin, and Wally Lester. It was first a 1958 hit single for the <a href="https://mastodon.online/tags/doowop" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>doowop</span></a> group <a href="https://mastodon.online/tags/theSkyliners" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>theSkyliners</span></a> on the Billboard Hot 100. <a href="https://mastodon.online/tags/CountryMusic" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>CountryMusic</span></a> singer <a href="https://mastodon.online/tags/RonnieMilsap" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>RonnieMilsap</span></a> had a hit with the song in 1991. American <a href="https://mastodon.online/tags/hardRock" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>hardRock</span></a> band <a href="https://mastodon.online/tags/GunsNRoses" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>GunsNRoses</span></a> also had some success in 1994 with their version of the song which reached the top 10 on the <a href="https://mastodon.online/tags/UKSinglesChart" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>UKSinglesChart</span></a>. <br><a href="https://youtu.be/ngZh6ZSRoYg" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">youtu.be/ngZh6ZSRoYg</span><span class="invisible"></span></a></p>',
#   'reblog': None,
#   'account': {'id': 110767005095620731,
#    'username': '50years_music',
#    'acct': '50years_music@mastodon.online',
#    'display_name': '50+ Music',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 7, 23, 0, 0, tzinfo=tzutc()),
#    'note': '<p>I am your personal DJ, playing a wide variety of popular music from the last 50+ years.  Follow me to remember the soundtrack of your life.</p>',
#    'url': 'https://mastodon.online/@50years_music',
#    'uri': 'https://mastodon.online/users/50years_music',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/110/767/005/095/620/731/original/4ba6c009c077e25a.jpg',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/110/767/005/095/620/731/original/4ba6c009c077e25a.jpg',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/110/767/005/095/620/731/original/9c357395c4bde958.jpg',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/110/767/005/095/620/731/original/9c357395c4bde958.jpg',
#    'followers_count': 300,
#    'following_count': 292,
#    'statuses_count': 35876,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Patreon',
#      'value': '<a href="https://www.patreon.com/50years_music" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">patreon.com/50years_music</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Twitter',
#      'value': '<a href="https://twitter.com/50years_music" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">twitter.com/50years_music</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Last.fm',
#      'value': '<a href="https://www.last.fm/user/fifty_music" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">last.fm/user/fifty_music</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'doowop', 'url': 'https://mastodon.social/tags/doowop'},
#    {'name': 'theskyliners',
#     'url': 'https://mastodon.social/tags/theskyliners'},
#    {'name': 'countrymusic',
#     'url': 'https://mastodon.social/tags/countrymusic'},
#    {'name': 'ronniemilsap',
#     'url': 'https://mastodon.social/tags/ronniemilsap'},
#    {'name': 'hardrock', 'url': 'https://mastodon.social/tags/hardrock'},
#    {'name': 'gunsnroses', 'url': 'https://mastodon.social/tags/gunsnroses'},
#    {'name': 'uksingleschart',
#     'url': 'https://mastodon.social/tags/uksingleschart'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595722414032,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 35, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'ca',
#   'uri': 'https://xarxa.cloud/users/lamarea/statuses/111260595365131330',
#   'url': 'https://xarxa.cloud/@lamarea/111260595365131330',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>Las fechas que maneja el PSOE para explicar los acuerdos e investir a Pedro Sánchez <a href="https://www.lamarea.com/2023/10/19/las-fechas-que-maneja-el-psoe-para-explicar-los-acuerdos-e-investir-a-pedro-sanchez/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">lamarea.com/2023/10/19/las-fec</span><span class="invisible">has-que-maneja-el-psoe-para-explicar-los-acuerdos-e-investir-a-pedro-sanchez/</span></a> <a href="https://xarxa.cloud/tags/Pol%C3%ADtica" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Política</span></a> <a href="https://xarxa.cloud/tags/Bot" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Bot</span></a> <a href="https://xarxa.cloud/tags/LaMarea" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LaMarea</span></a></p>',
#   'reblog': None,
#   'account': {'id': 1086371,
#    'username': 'lamarea',
#    'acct': 'lamarea@xarxa.cloud',
#    'display_name': 'lamarea',
#    'locked': False,
#    'bot': True,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2020, 1, 17, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Periodismo para gente independiente</p><p>Bot de lamarea.com</p>',
#    'url': 'https://xarxa.cloud/@lamarea',
#    'uri': 'https://xarxa.cloud/users/lamarea',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/001/086/371/original/4f7245c6e6c6f565.png',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/001/086/371/original/4f7245c6e6c6f565.png',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/001/086/371/original/b41835f74ba234be.jpg',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/001/086/371/original/b41835f74ba234be.jpg',
#    'followers_count': 1016,
#    'following_count': 2,
#    'statuses_count': 21,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Web',
#      'value': '<a href="https://www.lamarea.com/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">lamarea.com/</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Suscríbete',
#      'value': '<a href="https://kiosco.lamarea.com/categoria-producto/suscripciones/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">kiosco.lamarea.com/categoria-p</span><span class="invisible">roducto/suscripciones/</span></a>',
#      'verified_at': None},
#     {'name': 'Dona',
#      'value': '<a href="https://kiosco.lamarea.com/producto/donacion-al-proyecto-lamarea-com/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">kiosco.lamarea.com/producto/do</span><span class="invisible">nacion-al-proyecto-lamarea-com/</span></a>',
#      'verified_at': None},
#     {'name': 'RSS',
#      'value': '<a href="https://lamarea.com/feed" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">lamarea.com/feed</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [{'id': 111260595673540942,
#     'type': 'image',
#     'url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/673/540/942/original/809f4a5f4aecf27e.jpg',
#     'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/111/260/595/673/540/942/small/809f4a5f4aecf27e.jpg',
#     'remote_url': 'https://media.xarxa.cloud/media_attachments/files/111/260/595/285/758/600/original/568f8d9ae75b9411.jpg',
#     'preview_remote_url': None,
#     'text_url': None,
#     'meta': {'original': {'width': 800,
#       'height': 600,
#       'size': '800x600',
#       'aspect': 1.3333333333333333},
#      'small': {'width': 554,
#       'height': 416,
#       'size': '554x416',
#       'aspect': 1.3317307692307692}},
#     'description': None,
#     'blurhash': 'USBYU4xa9ZIoV@t6ofRj0KWB-pt7xuNGRjxu'}],
#   'mentions': [],
#   'tags': [{'name': 'lamarea', 'url': 'https://mastodon.social/tags/lamarea'},
#    {'name': 'bot', 'url': 'https://mastodon.social/tags/bot'},
#    {'name': 'politica', 'url': 'https://mastodon.social/tags/politica'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595714821926,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 40, 614000, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': True,
#   'spoiler_text': '\u200b',
#   'visibility': 'public',
#   'language': None,
#   'uri': 'https://misskey-square.net/notes/9l0g85uuh0',
#   'url': 'https://misskey-square.net/notes/9l0g85uuh0',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p><span>おまかの帝国</span></p>',
#   'reblog': None,
#   'account': {'id': 111005821859858153,
#    'username': 'Oisii_kohaku',
#    'acct': 'Oisii_kohaku@misskey-square.net',
#    'display_name': 'こはく',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 9, 4, 0, 0, tzinfo=tzutc()),
#    'note': '<p><span>【こはく】<br></span>\u200b:Miku_ai:\u200b<span>、ボカロ大好きです。<br>描いたイラストをたまにあげています。<br><br>アイコン▷</span><a href="https://misskey-square.net/@Riri22" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@Riri22</a><span> ちゃん(ありがとう！)<br>バナー▷ 自分(風呂入るプロファイル)</span></p>',
#    'url': 'https://misskey-square.net/@Oisii_kohaku',
#    'uri': 'https://misskey-square.net/users/9j84fcfusx',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/111/005/821/859/858/153/original/e790c0f24e621893.png',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/111/005/821/859/858/153/original/e790c0f24e621893.png',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/111/005/821/859/858/153/original/978a9e5af5721f03.webp',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/111/005/821/859/858/153/original/978a9e5af5721f03.webp',
#    'followers_count': 140,
#    'following_count': 74,
#    'statuses_count': 2219,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [{'shortcode': 'Miku_ai',
#      'url': 'https://files.mastodon.social/cache/custom_emojis/images/000/739/772/original/46489b22bdaa6390.gif',
#      'static_url': 'https://files.mastodon.social/cache/custom_emojis/images/000/739/772/static/46489b22bdaa6390.png',
#      'visible_in_picker': True}],
#    'fields': [{'name': '仲良しで大好き',
#      'value': '@1229@misskey.gg #🍉🍀\u3000#🎨🍉🫧',
#      'verified_at': None},
#     {'name': '絵描きともだちさま', 'value': '@requiem', 'verified_at': None},
#     {'name': '🫶',
#      'value': '@sakananoonigiri@submarin.online',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595696265450,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 40, 699000, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mastodon.social/users/malaysiagazette/statuses/111260595696265450',
#   'url': 'https://mastodon.social/@malaysiagazette/111260595696265450',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>PWM tidak dihargai <a href="https://mastodon.social/tags/malaysiagazette" class="mention hashtag" rel="tag">#<span>malaysiagazette</span></a></p><p><a href="https://malaysiagazette.com/2023/10/19/pwm-hilang-sabar-boikot-kerjasama-dengan-kpt/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">malaysiagazette.com/2023/10/19</span><span class="invisible">/pwm-hilang-sabar-boikot-kerjasama-dengan-kpt/</span></a></p>',
#   'reblog': None,
#   'application': {'name': 'Jetpack', 'website': 'https://jetpack.com/social/'},
#   'account': {'id': 110512337728405631,
#    'username': 'malaysiagazette',
#    'acct': 'malaysiagazette',
#    'display_name': 'Malaysia Gazette',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 6, 9, 0, 0, tzinfo=tzutc()),
#    'note': '<p>malaysiagazette.com memulakan operasi pada 1 Ogos 2013 bagi memenuhi cabaran dalam dunia kewartawanan</p>',
#    'url': 'https://mastodon.social/@malaysiagazette',
#    'uri': 'https://mastodon.social/users/malaysiagazette',
#    'avatar': 'https://files.mastodon.social/accounts/avatars/110/512/337/728/405/631/original/a23472e38da9db1d.png',
#    'avatar_static': 'https://files.mastodon.social/accounts/avatars/110/512/337/728/405/631/original/a23472e38da9db1d.png',
#    'header': 'https://files.mastodon.social/accounts/headers/110/512/337/728/405/631/original/eee9c6f7482f0232.jpeg',
#    'header_static': 'https://files.mastodon.social/accounts/headers/110/512/337/728/405/631/original/eee9c6f7482f0232.jpeg',
#    'followers_count': 47,
#    'following_count': 0,
#    'statuses_count': 10454,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'noindex': False,
#    'emojis': [],
#    'roles': [],
#    'fields': []},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'malaysiagazette',
#     'url': 'https://mastodon.social/tags/malaysiagazette'}],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595622396574,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 39, 577000, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://mastodon.social/users/masticadores/statuses/111260595622396574',
#   'url': 'https://mastodon.social/@masticadores/111260595622396574',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>your prey by Joni Karen Caggiano <a href="https://hotelmasticadoreshouse.wordpress.com/2023/10/19/your-prey-by-joni-karen-caggiano/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">hotelmasticadoreshouse.wordpre</span><span class="invisible">ss.com/2023/10/19/your-prey-by-joni-karen-caggiano/</span></a> #1, <a href="https://mastodon.social/tags/Hotel" class="mention hashtag" rel="tag">#<span>Hotel</span></a>, <a href="https://mastodon.social/tags/JoniCaggiano" class="mention hashtag" rel="tag">#<span>JoniCaggiano</span></a>, <a href="https://mastodon.social/tags/Poetry" class="mention hashtag" rel="tag">#<span>Poetry</span></a></p>',
#   'reblog': None,
#   'application': {'name': 'Web', 'website': None},
#   'account': {'id': 111209913632476178,
#    'username': 'masticadores',
#    'acct': 'masticadores',
#    'display_name': 'Masticadores (Revista digital)',
#    'locked': False,
#    'bot': True,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2023, 10, 10, 0, 0, tzinfo=tzutc()),
#    'note': '<p>200 escritores, 6 idiomas, 10 países (Usa, España, Brasil, Mexico, Argentina, Rumania, Francia, Italia, Canada.)</p>',
#    'url': 'https://mastodon.social/@masticadores',
#    'uri': 'https://mastodon.social/users/masticadores',
#    'avatar': 'https://files.mastodon.social/accounts/avatars/111/209/913/632/476/178/original/f1311dc93e6e8f00.jpg',
#    'avatar_static': 'https://files.mastodon.social/accounts/avatars/111/209/913/632/476/178/original/f1311dc93e6e8f00.jpg',
#    'header': 'https://mastodon.social/headers/original/missing.png',
#    'header_static': 'https://mastodon.social/headers/original/missing.png',
#    'followers_count': 2,
#    'following_count': 11,
#    'statuses_count': 23,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'noindex': False,
#    'emojis': [],
#    'roles': [],
#    'fields': [{'name': 'MasticadoresUSA.wordpress.com',
#      'value': '',
#      'verified_at': None},
#     {'name': 'Chewersmasticadores.wordpress.com',
#      'value': '',
#      'verified_at': None},
#     {'name': 'https://masticadores.com/', 'value': '', 'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'hotel', 'url': 'https://mastodon.social/tags/hotel'},
#    {'name': 'jonicaggiano',
#     'url': 'https://mastodon.social/tags/jonicaggiano'},
#    {'name': 'poetry', 'url': 'https://mastodon.social/tags/poetry'}],
#   'emojis': [],
#   'card': {'url': 'https://hotelmasticadoreshouse.wordpress.com/2023/10/19/your-prey-by-joni-karen-caggiano/',
#    'title': 'your prey by Joni Karen Caggiano',
#    'description': 'hurting heart, quivers sifting image, last beat why lie, uncharitable one what inordinate pain I unearth like shadow crow you pretend to love hawk grabs prey next day new lie, fashion fractures wha…',
#    'language': 'es',
#    'type': 'link',
#    'author_name': '',
#    'author_url': '',
#    'provider_name': 'Hotel ',
#    'provider_url': '',
#    'html': '',
#    'width': 1200,
#    'height': 920,
#    'image': 'https://files.mastodon.social/cache/preview_cards/images/076/437/752/original/0f281e111036f0ec.jpeg',
#    'image_description': '',
#    'embed_url': '',
#    'blurhash': 'U7Boy|-T9u0f9^57%2-o579a^*-o^*$%I;E2',
#    'published_at': datetime.datetime(2023, 10, 19, 7, 48, 25, tzinfo=tzutc())},
#   'poll': None},
#  {'id': 111260595618815953,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 37, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': True,
#   'spoiler_text': 'moustique',
#   'visibility': 'public',
#   'language': 'fr',
#   'uri': 'https://mastodon.opportunis.me/users/Grandasse_/statuses/111260595506183585',
#   'url': 'https://mastodon.opportunis.me/@Grandasse_/111260595506183585',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': "<p>Tellement saoulé de pas avoir pu déglinguer le moustique cette nuit, je me suis enfoui sous ma couette (erk)<br>Et visiblement j'avais ma main à l'extérieur, je suis piqué sur le doigt</p>",
#   'reblog': None,
#   'account': {'id': 836108,
#    'username': 'Grandasse_',
#    'acct': 'Grandasse_@mastodon.opportunis.me',
#    'display_name': 'Grandasse',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2019, 6, 17, 0, 0, tzinfo=tzutc()),
#    'note': '<p>Pronoms masculins (ou féminins si je suis dans un groupe majoritairement féminin)</p><p>Adepte du <a href="https://mastodon.opportunis.me/tags/lockpicking" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>lockpicking</span></a>.<br>Ici je cause <a href="https://mastodon.opportunis.me/tags/musique" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>musique</span></a> et je poste des photos de couchers de soleil, et j\'aime créer des <a href="https://mastodon.opportunis.me/tags/glitch" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>glitch</span></a></p><p>Glitches du cul : <span class="h-card" translate="no"><a href="https://mastodon.opportunis.me/@Grandasse" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>Grandasse</span></a></span></p>',
#    'url': 'https://mastodon.opportunis.me/@Grandasse_',
#    'uri': 'https://mastodon.opportunis.me/users/Grandasse_',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/000/836/108/original/9d738034f8c5f8a0.jpg',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/000/836/108/original/9d738034f8c5f8a0.jpg',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/000/836/108/original/a1d569239ae47849.jpg',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/000/836/108/original/a1d569239ae47849.jpg',
#    'followers_count': 313,
#    'following_count': 340,
#    'statuses_count': 18648,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': [{'name': 'Instrument', 'value': 'Batterie', 'verified_at': None},
#     {'name': 'Musique',
#      'value': '<a href="http://solventis.fr" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">http://</span><span class="">solventis.fr</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [],
#   'emojis': [],
#   'card': None,
#   'poll': None},
#  {'id': 111260595613938456,
#   'created_at': datetime.datetime(2023, 10, 19, 7, 52, 37, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://kolektiva.social/users/phistorians/statuses/111260595467187170',
#   'url': 'https://kolektiva.social/@phistorians/111260595467187170',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 0,
#   'edited_at': None,
#   'content': '<p>✨Brand New Episode ✨</p><p>Episode 143: Special Victims Unit</p><p>In the aftermath of Postumius’ murder in 414 BCE, there’s nothing for it but a proper old fashioned investigation! What will our detectives find once they peel back the layers of the case?</p><p><a href="https://kolektiva.social/tags/Podcast" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Podcast</span></a> <a href="https://kolektiva.social/tags/AncientRome" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>AncientRome</span></a> <a href="https://kolektiva.social/tags/History" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>History</span></a></p><p><a href="https://partialhistorians.com/2023/10/19/episode-143-special-victims-unit/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">partialhistorians.com/2023/10/</span><span class="invisible">19/episode-143-special-victims-unit/</span></a></p>',
#   'reblog': None,
#   'account': {'id': 109362321197812721,
#    'username': 'phistorians',
#    'acct': 'phistorians@kolektiva.social',
#    'display_name': 'The Partial Historians',
#    'locked': False,
#    'bot': False,
#    'discoverable': True,
#    'group': False,
#    'created_at': datetime.datetime(2022, 11, 18, 0, 0, tzinfo=tzutc()),
#    'note': '<p>After surviving exposure at birth, these unconventional academics realised they were destined to found the greatest Ancient Roman History podcast! 🏛📯⚔️\u2028\u2028Our main series follows the history of Rome from the founding of the city. We also interview scholars and fantastic people about the ancient world.\u2029Dr Rad (she/her) specialises in Spartacus. Dr G (she/her) specialises in the Vestal Virgins. \u2028\u2028📍 Dharug and Bidjigal Country.\u2028\u2028<a href="https://kolektiva.social/tags/Podcast" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Podcast</span></a> <a href="https://kolektiva.social/tags/Ancient" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Ancient</span></a> <a href="https://kolektiva.social/tags/Histodon" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Histodon</span></a> <a href="https://kolektiva.social/tags/Historian" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Historian</span></a> <a href="https://kolektiva.social/tags/Rome" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Rome</span></a> <a href="https://kolektiva.social/tags/AncientHistory" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>AncientHistory</span></a></p>',
#    'url': 'https://kolektiva.social/@phistorians',
#    'uri': 'https://kolektiva.social/users/phistorians',
#    'avatar': 'https://files.mastodon.social/cache/accounts/avatars/109/362/321/197/812/721/original/71795e70bbb23b7c.png',
#    'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/109/362/321/197/812/721/original/71795e70bbb23b7c.png',
#    'header': 'https://files.mastodon.social/cache/accounts/headers/109/362/321/197/812/721/original/d2705f2da7681c0a.png',
#    'header_static': 'https://files.mastodon.social/cache/accounts/headers/109/362/321/197/812/721/original/d2705f2da7681c0a.png',
#    'followers_count': 1131,
#    'following_count': 695,
#    'statuses_count': 729,
#    'last_status_at': datetime.datetime(2023, 10, 19, 0, 0),
#    'emojis': [],
#    'fields': [{'name': '🔗',
#      'value': '<a href="https://linktr.ee/ThePartialHistorians" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">linktr.ee/ThePartialHistorians</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Website',
#      'value': '<a href="https://partialhistorians.com/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="">partialhistorians.com/</span><span class="invisible"></span></a>',
#      'verified_at': None},
#     {'name': 'Spotify',
#      'value': '<a href="https://open.spotify.com/show/4qUMqaB4GSAYEXq6CNYvyS" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.spotify.com/show/4qUMqaB4</span><span class="invisible">GSAYEXq6CNYvyS</span></a>',
#      'verified_at': None},
#     {'name': 'YouTube',
#      'value': '<a href="https://www.youtube.com/@partialhistorians" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">youtube.com/@partialhistorians</span><span class="invisible"></span></a>',
#      'verified_at': None}]},
#   'media_attachments': [],
#   'mentions': [],
#   'tags': [{'name': 'podcast', 'url': 'https://mastodon.social/tags/podcast'},
#    {'name': 'ancientrome', 'url': 'https://mastodon.social/tags/ancientrome'},
#    {'name': 'history', 'url': 'https://mastodon.social/tags/history'}],
#   'emojis': [],
#   'card': None,
#   'poll': None}]

# %%
import csv


# Define the CSV file name
csv_file = 'mastodon_posts.csv'

# Define the CSV field names
fieldnames = [
    'id', 'created_at', 'in_reply_to_id', 'in_reply_to_account_id', 'sensitive',
    'spoiler_text', 'visibility', 'language', 'uri', 'url', 'replies_count',
    'reblogs_count', 'favourites_count', 'content', 'edited_at',
    'account_id', 'account_username', 'account_acct', 'account_display_name',
    'account_locked', 'account_bot', 'account_discoverable', 'account_group',
    'account_created_at', 'account_note', 'account_url', 'account_uri',
    'account_avatar', 'account_avatar_static', 'account_header', 'account_header_static',
    'account_followers_count', 'account_following_count', 'account_statuses_count',
    'account_last_status_at',
    'media_attachments_id', 'media_attachments_type', 'media_attachments_url',
    'media_attachments_preview_url', 'media_attachments_remote_url', 'media_attachments_description',
    'media_attachments_blurhash'
]

# Create and open the CSV file for writing
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    # Write the header row
    writer.writeheader()
    
    # Write the data rows
    for post in public_posts:
        media_attachments = post.get('media_attachments', [])  # Get media attachments or an empty list
        media_attachment = media_attachments[0] if media_attachments else {}  # Get the first attachment or an empty dictionary
        
        writer.writerow({
            'id': post['id'],
            'created_at': post['created_at'],
            'in_reply_to_id': post['in_reply_to_id'],
            'in_reply_to_account_id': post['in_reply_to_account_id'],
            'sensitive': post['sensitive'],
            'spoiler_text': post['spoiler_text'],
            'visibility': post['visibility'],
            'language': post['language'],
            'uri': post['uri'],
            'url': post['url'],
            'replies_count': post['replies_count'],
            'reblogs_count': post['reblogs_count'],
            'favourites_count': post['favourites_count'],
            'content': post['content'],
            'edited_at': post['edited_at'],
            'account_id': post['account']['id'],
            'account_username': post['account']['username'],
            'account_acct': post['account']['acct'],
            'account_display_name': post['account']['display_name'],
            'account_locked': post['account']['locked'],
            'account_bot': post['account']['bot'],
            'account_discoverable': post['account']['discoverable'],
            'account_group': post['account']['group'],
            'account_created_at': post['account']['created_at'],
            'account_note': post['account']['note'],
            'account_url': post['account']['url'],
            'account_uri': post['account']['uri'],
            'account_avatar': post['account']['avatar'],
            'account_avatar_static': post['account']['avatar_static'],
            'account_header': post['account']['header'],
            'account_header_static': post['account']['header_static'],
            'account_followers_count': post['account']['followers_count'],
            'account_following_count': post['account']['following_count'],
            'account_statuses_count': post['account']['statuses_count'],
            'account_last_status_at': post['account']['last_status_at'],
            'media_attachments_id': media_attachment.get('id', ''),
            'media_attachments_type': media_attachment.get('type', ''),
            'media_attachments_url': media_attachment.get('url', ''),
            'media_attachments_preview_url': media_attachment.get('preview_url', ''),
            'media_attachments_remote_url': media_attachment.get('remote_url', ''),
            'media_attachments_description': media_attachment.get('description', ''),
            'media_attachments_blurhash': media_attachment.get('blurhash', '')
        })

print(f'Data has been saved to {csv_file}')
# Out:
# Data has been saved to mastodon_posts.csv

# %%
import pandas as pd
dffff=pd.read_csv('mastodon_posts.csv')
dffff
# Out:
#                    id                        created_at  in_reply_to_id
# 0  111260595831428351         2023-10-19 07:52:39+00:00    1.112606e+17  \
# 1  111260595817377032         2023-10-19 07:51:35+00:00    1.107808e+17
# 2  111260595803718108         2023-10-19 07:52:40+00:00             NaN
# 3  111260595763020092         2023-10-19 07:52:41+00:00             NaN
# 4  111260595722414032         2023-10-19 07:52:35+00:00             NaN
# 5  111260595714821926  2023-10-19 07:52:40.614000+00:00             NaN
# 6  111260595696265450  2023-10-19 07:52:40.699000+00:00             NaN
# 7  111260595622396574  2023-10-19 07:52:39.577000+00:00             NaN
# 8  111260595618815953         2023-10-19 07:52:37+00:00             NaN
# 9  111260595613938456         2023-10-19 07:52:37+00:00             NaN
#
#    in_reply_to_account_id  sensitive spoiler_text visibility language
# 0            1.107308e+17      False          NaN     public       en  \
# 1            5.062470e+05      False          NaN     public       fr
# 2                     NaN      False          NaN     public       fr
# 3                     NaN      False          NaN     public       en
# 4                     NaN      False          NaN     public       ca
# 5                     NaN       True            ​     public      NaN
# 6                     NaN      False          NaN     public       en
# 7                     NaN      False          NaN     public       en
# 8                     NaN       True    moustique     public       fr
# 9                     NaN      False          NaN     public       en
#
#                                                  uri
# 0  https://neuromatch.social/users/fsandhaeger/st...  \
# 1  https://mamot.fr/users/EnercoConseils/statuses...
# 2  https://lepoulsdumonde.com/users/bot_bp/status...
# 3  https://mastodon.online/users/50years_music/st...
# 4  https://xarxa.cloud/users/lamarea/statuses/111...
# 5        https://misskey-square.net/notes/9l0g85uuh0
# 6  https://mastodon.social/users/malaysiagazette/...
# 7  https://mastodon.social/users/masticadores/sta...
# 8  https://mastodon.opportunis.me/users/Grandasse...
# 9  https://kolektiva.social/users/phistorians/sta...
#
#                                                  url  ...
# 0  https://neuromatch.social/@fsandhaeger/1112605...  ...  \
# 1  https://mamot.fr/@EnercoConseils/1112605914251...  ...
# 2  https://lepoulsdumonde.com/@bot_bp/11126059567...  ...
# 3  https://mastodon.online/@50years_music/1112605...  ...
# 4    https://xarxa.cloud/@lamarea/111260595365131330  ...
# 5        https://misskey-square.net/notes/9l0g85uuh0  ...
# 6  https://mastodon.social/@malaysiagazette/11126...  ...
# 7  https://mastodon.social/@masticadores/11126059...  ...
# 8  https://mastodon.opportunis.me/@Grandasse_/111...  ...
# 9  https://kolektiva.social/@phistorians/11126059...  ...
#
#    account_following_count  account_statuses_count  account_last_status_at
# 0                      368                      21     2023-10-19 00:00:00  \
# 1                      111                    1676     2023-10-19 00:00:00
# 2                        0                    1629     2023-10-19 00:00:00
# 3                      292                   35876     2023-10-19 00:00:00
# 4                        2                      21     2023-10-19 00:00:00
# 5                       74                    2219     2023-10-19 00:00:00
# 6                        0                   10454     2023-10-19 00:00:00
# 7                       11                      23     2023-10-19 00:00:00
# 8                      340                   18648     2023-10-19 00:00:00
# 9                      695                     729     2023-10-19 00:00:00
#
#   media_attachments_id  media_attachments_type
# 0         1.112606e+17                   image  \
# 1                  NaN                     NaN
# 2         1.112606e+17                   image
# 3                  NaN                     NaN
# 4         1.112606e+17                   image
# 5                  NaN                     NaN
# 6                  NaN                     NaN
# 7                  NaN                     NaN
# 8                  NaN                     NaN
# 9                  NaN                     NaN
#
#                                media_attachments_url
# 0  https://files.mastodon.social/cache/media_atta...  \
# 1                                                NaN
# 2  https://files.mastodon.social/cache/media_atta...
# 3                                                NaN
# 4  https://files.mastodon.social/cache/media_atta...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                        media_attachments_preview_url
# 0  https://files.mastodon.social/cache/media_atta...  \
# 1                                                NaN
# 2  https://files.mastodon.social/cache/media_atta...
# 3                                                NaN
# 4  https://files.mastodon.social/cache/media_atta...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                         media_attachments_remote_url
# 0  https://neuromatch.social/system/media_attachm...  \
# 1                                                NaN
# 2  https://i.lepoulsdumonde.com/media_attachments...
# 3                                                NaN
# 4  https://media.xarxa.cloud/media_attachments/fi...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#           media_attachments_description            media_attachments_blurhash
# 0                                   NaN  UFRC-=_4%MjaM{xukBf5%MNFkCWBRQoyt7ae
# 1                                   NaN                                   NaN
# 2  un média posté par le compte Twitter  UgIqoj^Is+S502kYRjV?xvMyRkoLj;xtofWX
# 3                                   NaN                                   NaN
# 4                                   NaN  USBYU4xa9ZIoV@t6ofRj0KWB-pt7xuNGRjxu
# 5                                   NaN                                   NaN
# 6                                   NaN                                   NaN
# 7                                   NaN                                   NaN
# 8                                   NaN                                   NaN
# 9                                   NaN                                   NaN
#
# [10 rows x 42 columns]

# %%
dffff.columns
# Out:
# Index(['id', 'created_at', 'in_reply_to_id', 'in_reply_to_account_id',
#        'sensitive', 'spoiler_text', 'visibility', 'language', 'uri', 'url',
#        'replies_count', 'reblogs_count', 'favourites_count', 'content',
#        'edited_at', 'account_id', 'account_username', 'account_acct',
#        'account_display_name', 'account_locked', 'account_bot',
#        'account_discoverable', 'account_group', 'account_created_at',
#        'account_note', 'account_url', 'account_uri', 'account_avatar',
#        'account_avatar_static', 'account_header', 'account_header_static',
#        'account_followers_count', 'account_following_count',
#        'account_statuses_count', 'account_last_status_at',
#        'media_attachments_id', 'media_attachments_type',
#        'media_attachments_url', 'media_attachments_preview_url',
#        'media_attachments_remote_url', 'media_attachments_description',
#        'media_attachments_blurhash'],
#       dtype='object')

# %%
import csv

# Define the CSV file name
csv_file = 'mastodon_posts_analyzed.csv'

# Define the CSV field names for the selected columns
fieldnames = [
    'account_id', 'account_username', 'account_followers_count',
    'replies_count', 'reblogs_count', 'favourites_count',
    'account_created_at', 'url', 'language', 'content', 'media_attachments_type'
]

# Create and open the CSV file for writing
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    # Write the header row
    writer.writeheader()

    # Write the data rows
    for post in public_posts:
        writer.writerow({
            'account_id': post['account']['id'],
            'account_username': post['account']['username'],
            'account_followers_count': post['account']['followers_count'],
            'replies_count': post['replies_count'],
            'reblogs_count': post['reblogs_count'],
            'favourites_count': post['favourites_count'],
            'account_created_at': post['account']['created_at'],
            'url': post['url'],
            'language': post['language'],
            'content': post['content'],
            'media_attachments_type': post['media_attachments'][0]['type'] if post['media_attachments'] else None
        })

print(f'Data has been saved to {csv_file}')
# Out:
# Data has been saved to mastodon_posts_analyzed.csv

# %%
dfff=pd.read_csv('mastodon_posts_analyzed.csv')
dfff
# Out:
#            account_id account_username  account_followers_count
# 0  110730813077137029      fsandhaeger                      105  \
# 1              506247   EnercoConseils                      208
# 2  109739396230937969           bot_bp                       95
# 3  110767005095620731    50years_music                      300
# 4             1086371          lamarea                     1016
# 5  111005821859858153     Oisii_kohaku                      140
# 6  110512337728405631  malaysiagazette                       47
# 7  111209913632476178     masticadores                        2
# 8              836108       Grandasse_                      313
# 9  109362321197812721      phistorians                     1131
#
#    replies_count  reblogs_count  favourites_count         account_created_at
# 0              0              0                 0  2023-07-14 00:00:00+00:00  \
# 1              0              0                 0  2018-08-30 00:00:00+00:00
# 2              0              0                 0  2023-01-23 00:00:00+00:00
# 3              0              0                 0  2023-07-23 00:00:00+00:00
# 4              0              0                 0  2020-01-17 00:00:00+00:00
# 5              0              0                 0  2023-09-04 00:00:00+00:00
# 6              0              0                 0  2023-06-09 00:00:00+00:00
# 7              0              0                 0  2023-10-10 00:00:00+00:00
# 8              0              0                 0  2019-06-17 00:00:00+00:00
# 9              0              0                 0  2022-11-18 00:00:00+00:00
#
#                                                  url language
# 0  https://neuromatch.social/@fsandhaeger/1112605...       en  \
# 1  https://mamot.fr/@EnercoConseils/1112605914251...       fr
# 2  https://lepoulsdumonde.com/@bot_bp/11126059567...       fr
# 3  https://mastodon.online/@50years_music/1112605...       en
# 4    https://xarxa.cloud/@lamarea/111260595365131330       ca
# 5        https://misskey-square.net/notes/9l0g85uuh0      NaN
# 6  https://mastodon.social/@malaysiagazette/11126...       en
# 7  https://mastodon.social/@masticadores/11126059...       en
# 8  https://mastodon.opportunis.me/@Grandasse_/111...       fr
# 9  https://kolektiva.social/@phistorians/11126059...       en
#
#                                              content media_attachments_type
# 0  <p>Choice signals dynamically shifted from sen...                  image
# 1  <p>Je vais vous donner mon opinion à mon tout,...                    NaN
# 2  <p>🍽️Les 70 ans de la Cocotte-Minute&nbsp;: ch...                  image
# 3  <p>"Since I Don't Have You" is a song written ...                    NaN
# 4  <p>Las fechas que maneja el PSOE para explicar...                  image
# 5                         <p><span>おまかの帝国</span></p>                    NaN
# 6  <p>PWM tidak dihargai <a href="https://mastodo...                    NaN
# 7  <p>your prey by Joni Karen Caggiano <a href="h...                    NaN
# 8  <p>Tellement saoulé de pas avoir pu déglinguer...                    NaN
# 9  <p>✨Brand New Episode ✨</p><p>Episode 143: Spe...                    NaN

# %%
dfff.columns
# Out:
# Index(['account_id', 'account_username', 'account_followers_count',
#        'replies_count', 'reblogs_count', 'favourites_count',
#        'account_created_at', 'url', 'language', 'content'],
#       dtype='object')
